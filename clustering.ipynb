# %%
from google.colab import drive
import cv2
import os
from google.colab.patches import cv2_imshow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.cluster import AgglomerativeClustering
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df=pd.read_csv('/content/gdrive/MyDrive/Im beside you./face_images/f584_data.csv')
df=df.drop(df.columns[0],axis=1)

# %%
df
# Out:
#               0         1         2         3         4         5         6  \
# 0     -0.018006  0.046093  0.008085 -0.017251 -0.086119 -0.044587 -0.033877
# 1     -0.058578  0.022604  0.067431 -0.026108 -0.093234 -0.051767 -0.053279
# 2     -0.076119  0.113240  0.059330 -0.076114 -0.132807 -0.036949 -0.082213
# 3     -0.067092  0.119958  0.059546 -0.071240 -0.135002 -0.044356 -0.085840
# 4     -0.055548  0.052059  0.052449 -0.048049 -0.059530 -0.063898 -0.044044
# ...         ...       ...       ...       ...       ...       ...       ...
# 14427 -0.101966  0.088164  0.082060 -0.048275 -0.138456 -0.057763 -0.106112
# 14428 -0.126286  0.055953  0.002436 -0.090499 -0.147506 -0.034150 -0.067131
# 14429 -0.038162  0.159277  0.035639 -0.113861 -0.121384 -0.004843 -0.086543
# 14430 -0.038695  0.035909  0.072976  0.014505 -0.048495 -0.045014 -0.071135
# 14431 -0.100543  0.071181  0.002065 -0.093831 -0.142844 -0.029175 -0.079795
#
# ...

# %%
path = '/content/gdrive/MyDrive/Im beside you./face_images/f5845e49-256f-4d70-9214-47bd5358c9d1'

# %% [markdown]
# # **Break**

# %%
x=df.drop(df.columns[128],axis=1)

# %%
x
# Out:
#               0         1         2         3         4         5         6  \
# 0     -0.040635  0.043664  0.007770 -0.070538 -0.039294 -0.052943 -0.093208
# 1     -0.028558  0.036748  0.025254 -0.071964 -0.046369 -0.061980 -0.065315
# 2     -0.021697  0.023906  0.006089 -0.068671 -0.059082 -0.047076 -0.084882
# 3     -0.018334  0.043747  0.014991 -0.074854 -0.059615 -0.049641 -0.079275
# 4     -0.021728  0.055539  0.028897 -0.077863 -0.057480 -0.054780 -0.074188
# ...         ...       ...       ...       ...       ...       ...       ...
# 10273 -0.036697  0.055431  0.022071 -0.100278 -0.125519 -0.038632 -0.105946
# 10274 -0.023049  0.046520  0.038919 -0.085512 -0.051215 -0.027983 -0.048614
# 10275 -0.081402  0.145748  0.100303 -0.078600 -0.142887 -0.051232 -0.110460
# 10276 -0.030618  0.054217  0.019190 -0.099244 -0.123836 -0.043112 -0.100654
# 10277 -0.028081  0.053772  0.040747 -0.097027 -0.046518 -0.036449 -0.050833
#
# ...

# %%
from re import X
#Set number of clusters at initialisation time
k_means = KMeans(n_clusters=4)
#Run the clustering algorithm
model = k_means.fit(x)
model 
#Generate cluster predictions and store in y_hat
y_hat = k_means.predict(x)

# %%
y_hat
# Out:
# array([0, 0, 0, ..., 2, 1, 0], dtype=int32)

# %%
for i in range(len(y_hat)):
    if y_hat[i]==0:
      val=df.iloc[i][128]
      img_path = path+'/'+val
      img=cv2.imread(img_path)
      cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df['Predicted ID'] = y_hat

# %%
d = df[df.columns[128:130]]

# %%
d.to_csv('f584-predict.csv')
# !cp f584-predict.csv "/content/gdrive/MyDrive/Im beside you./face_images"
