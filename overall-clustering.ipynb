# %%
from google.colab import drive
import cv2
import os
from google.colab.patches import cv2_imshow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.cluster import AgglomerativeClustering
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df3=pd.read_csv('/content/gdrive/MyDrive/Im beside you./Kushagra-Project2/f584_data.csv')
df2=pd.read_csv('/content/gdrive/MyDrive/Im beside you./Kushagra-Project2/dd40_data.csv')
df1=pd.read_csv('/content/gdrive/MyDrive/Im beside you./Kushagra-Project2/a055_data.csv')
df = pd.concat([df1,df2])
df = pd.concat([df,df3])
df=df.drop(df.columns[0],axis=1)

# %%
x=df.drop(df.columns[128],axis=1)

# %%
from re import X
#Set number of clusters at initialisation time
k_means = KMeans(n_clusters=4)
#Run the clustering algorithm
model = k_means.fit(x)
model 
#Generate cluster predictions and store in y_hat
y_hat = k_means.predict(x)

# %%
y_hat
# Out:
# array([0, 0, 2, ..., 2, 1, 0], dtype=int32)

# %%
df['Predicted ID'] = y_hat

# %%
d = df[df.columns[128:130]]

# %%
d.to_csv('overall-predict.csv')
# !cp overall-predict.csv "/content/gdrive/MyDrive/Im beside you./Kushagra-Project2/results"
